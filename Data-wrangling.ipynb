# %% [markdown]
# # DATA WRANGLING

# %%
import pandas as pd
import numpy as np
import re
personality_data = pd.read_csv('personality_scores.csv', sep=';')
department_data =pd.read_csv('departments.csv', sep=';')

personality_data
# Out:
#         ID Section 5 of 6 [I am always prepared.]  \
# 0        0                                 (3, 5)
# 1        1                                 (3, 5)
# 2        2                                 (3, 5)
# 3        3                                 (3, 5)
# 4        4                                 (3, 3)
# ...    ...                                    ...
# 1550  1550                                 (3, 5)
# 1551  1551                                 (3, 3)
# 1552  1552                                 (3, 5)
# 1553  1553                                 (3, 5)
# 1554  1554                                 (3, 3)
#
#      Section 5 of 6 [I am easily disturbed.]  \
# 0                                     (4, 5)
# 1                                     (4, 5)
# 2                                     (4, 3)
# 3                                     (4, 5)
# 4                                     (4, 5)
# ...                                      ...
# ...

# %%
personality_clean= personality_data.drop_duplicates(subset = 'ID')
personality_clean= personality_data.set_index('ID')

# %%
display(personality_clean)
# Out:
#      Section 5 of 6 [I am always prepared.]  \
# ID
# 0                                    (3, 5)
# 1                                    (3, 5)
# 2                                    (3, 5)
# 3                                    (3, 5)
# 4                                    (3, 3)
# ...                                     ...
# 1550                                 (3, 5)
# 1551                                 (3, 3)
# 1552                                 (3, 5)
# 1553                                 (3, 5)
# 1554                                 (3, 3)
#
#      Section 5 of 6 [I am easily disturbed.]  \
# ID
# 0                                     (4, 5)
# 1                                     (4, 5)
# 2                                     (4, 3)
# 3                                     (4, 5)
# 4                                     (4, 5)
# ...                                      ...
# 1550                                  (4, 5)
# 1551                                  (4, 5)
# ...

# %%
#dropping column with missing all mising values
personality_new=personality_clean.dropna(axis = 1)
personality_new.head(3)
# Out:
#    Section 5 of 6 [I am always prepared.]  \
# ID
# 0                                  (3, 5)
# 1                                  (3, 5)
# 2                                  (3, 5)
#
#    Section 5 of 6 [I am easily disturbed.]  \
# ID
# 0                                   (4, 5)
# 1                                   (4, 5)
# 2                                   (4, 3)
#
#    Section 5 of 6 [I am exacting (demanding) in my work.]  \
# ID
# 0                                              (3, 5)
# 1                                              (3, 5)
# 2                                              (3, 3)
#
#    Section 5 of 6 [I am full of ideas.]  \
# ID
# 0                                (5, 5)
# 1                                (5, 5)
# 2                                (5, 5)
#
#    Section 5 of 6 [I am interested in people.]  \
# ID
# 0                                       (2, 3)
# 1                                       (2, 5)
# 2                                       (2, 5)
#
# ...

# %%
personality_new.columns
# Out:
# Index(['Section 5 of 6 [I am always prepared.]',
#        'Section 5 of 6 [I am easily disturbed.]',
#        'Section 5 of 6 [I am exacting (demanding) in my work.]',
#        'Section 5 of 6 [I am full of ideas.]',
#        'Section 5 of 6 [I am interested in people.]',
#        'Section 5 of 6 [I am not interested in abstract ideas.]',
#        'Section 5 of 6 [I am not interested in other people's problems.]',
#        'Section 5 of 6 [I am not really interested in others.]',
#        'Section 5 of 6 [I am quick to understand things.]',
#        'Section 5 of 6 [I am quiet around strangers.]',
#        'Section 5 of 6 [I am relaxed most of the time.]',
#        'Section 5 of 6 [I am the life of the party.]',
#        'Section 5 of 6 [I change my mood a lot.]',
#        'Section 5 of 6 [I do not have a good imagination.]',
#        'Section 5 of 6 [I don't like to draw attention to myself.]',
#        'Section 5 of 6 [I don't mind being the center of attention.]',
# ...

# %%
# columns renaming
personality_new.rename(columns = {
       'Section 5 of 6 [I am always prepared.]': "I am always prepared",
       'Section 5 of 6 [I am easily disturbed.]': "I am easily disturbed",
       'Section 5 of 6 [I am exacting (demanding) in my work.]': "I am exacting (demanding) in my work",
       'Section 5 of 6 [I am full of ideas.]': "I am full of ideas",
       'Section 5 of 6 [I am interested in people.]': "I am interested in people",
       'Section 5 of 6 [I am not interested in abstract ideas.]': "I am not interested in abstract ideas",
       "Section 5 of 6 [I am not interested in other people's problems.]" : "I am not interested in other people's problems",
       'Section 5 of 6 [I am not really interested in others.]': "I am not really interested in others",
       'Section 5 of 6 [I am quick to understand things.]' : "I am quick to understand things",
       'Section 5 of 6 [I am quiet around strangers.]' : "I am quiet around strangers",
       'Section 5 of 6 [I am relaxed most of the time.]' : "I am relaxed most of the time",
       'Section 5 of 6 [I am the life of the party.]' : "I am the life of the party",
       'Section 5 of 6 [I change my mood a lot.]' : "I change my mood a lot",
       'Section 5 of 6 [I do not have a good imagination.]' : "I do not have a good imagination",
       "Section 5 of 6 [I don't like to draw attention to myself.]" : "I don't like to draw attention to myself",
       "Section 5 of 6 [I don't mind being the center of attention.]" : "I don't mind being the center of attention",
       "Section 5 of 6 [I don't talk a lot.]" : "I don't talk a lot",
       'Section 5 of 6 [I feel comfortable around people.]' : "I feel comfortable around people",
       'Section 5 of 6 [I feel little concern for others.]' : "I feel little concern for others",
       "Section 5 of 6 [I feel others' emotions.]" : "I feel others' emotions",
       'Section 5 of 6 [I follow a schedule.]' : "I follow a schedule",
       'Section 5 of 6 [I get chores done right away.]' : "I get chores done right away" ,
       'Section 5 of 6 [I get irritated easily.]' : "I get irritated easily",
       'Section 5 of 6 [I get stressed out easily.]' : "I get stressed out easily",
       'Section 5 of 6 [I get upset easily.]' : "I get upset easily",
       'Section 5 of 6 [I have a rich vocabulary.]' : "I have a rich vocabulary",
       'Section 5 of 6 [I have a soft (kind) heart.]' : "I have a soft (kind) heart",
       'Section 5 of 6 [I have a vivid imagination.]' : "I have a vivid imagination",
       'Section 5 of 6 [I have difficulty understanding abstract ideas.]' : "I have difficulty understanding abstract ideas",
       'Section 5 of 6 [I have excellent ideas.]' : "I have excellent ideas",
       'Section 5 of 6 [I have frequent mood swings.]' : "I have frequent mood swings",
       'Section 5 of 6 [I have little to say.]' : "I have little to say",
       'Section 5 of 6 [I insult people.]' : "I insult people",
       'Section 5 of 6 [I keep in the background.]' : "I keep in the background",
       'Section 5 of 6 [I leave my belongings lying around.]' : "I leave my belongings lying around",
       'Section 5 of 6 [I like order.]' : "I like order",
       'Section 5 of 6 [I make a mess of things.]' : "I make a mess of thing",
       'Section 5 of 6 [I make people feel at ease.]' : "I make people feel at ease",
       'Section 5 of 6 [I neglect my duties.]' : "I neglect my duties",
       'Section 5 of 6 [I often feel blue (down).]' : "I often feel blue (down)",
       'Section 5 of 6 [I often forget to put things back in their proper place]' : "I often forget to put things back in their proper place",
       'Section 5 of 6 [I pay attention to details.]' : "I pay attention to details",
       'Section 5 of 6 [I seldom feel blue (down).]' : "I seldom feel blue (down)",
       'Section 5 of 6 [I spend time reflecting on things.]' : "I spend time reflecting on things",
       'Section 5 of 6 [I start conversations.]' : "I start conversations",
       "Section 5 of 6 [I sympathize with others' feelings.]" : "I sympathize with others' feelings",
       'Section 5 of 6 [I take time out for others.]' : "I take time out for others",
       'Section 5 of 6 [I talk to a lot of different people at parties.]' : "I talk to a lot of different people at parties",
       'Section 5 of 6 [I use difficult words.]' : "I use difficult words",
       'Section 5 of 6 [I worry about things.]' : "I worry about things"
    }, inplace = True)
# Out:
# c:\users\dell\miniconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
personality_new.head(2)
# Out:
#    I am always prepared I am easily disturbed  \
# ID
# 0                (3, 5)                (4, 5)
# 1                (3, 5)                (4, 5)
#
#    I am exacting (demanding) in my work I am full of ideas  \
# ID
# 0                                (3, 5)             (5, 5)
# 1                                (3, 5)             (5, 5)
#
#    I am interested in people I am not interested in abstract ideas  \
# ID
# 0                     (2, 3)                                (5, 3)
# 1                     (2, 5)                                (5, 3)
#
#    I am not interested in other people's problems  \
# ID
# 0                                          (2, 3)
# 1                                          (2, 5)
#
#    I am not really interested in others I am quick to understand things  \
# ID
# 0                                (2, 5)                          (5, 5)
# 1                                (2, 5)                          (5, 5)
#
# ...
